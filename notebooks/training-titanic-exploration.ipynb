# %% [markdown]
# # Create s3 client and download data from minio

# %% [markdown]
# # Random split train / test

# %% [markdown]
# # Train ML model

# %% [markdown]
# # Evaluate ML model

# %% [markdown]
# # Training Pipeline
